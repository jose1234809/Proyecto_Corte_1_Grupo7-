# %% [markdown]
# # 📝 PSEUDOCÓDIGO - SISTEMA DE GESTIÓN DE PRECIOS GAME ZONE
#
# ## INICIO DEL PROGRAMA
#
# ### PASO 1: BIENVENIDA Y CONTEXTO
# ```
# MOSTRAR banner de bienvenida a GAME ZONE
# MOSTRAR contexto del servicio
# MOSTRAR objetivo del sistema
# MOSTRAR información de productos disponibles
# MOSTRAR proceso a seguir
# ```
#
# ### PASO 2: ENTRADA DE DATOS - LISTA DE PRODUCTOS
# ```
# CREAR lista de productos con (nombre, precio):
#     - Nintendo Switch Pro: $350
#     - Control Xbox Series X: $70
#     - The Legend of Zelda: $80
#     - PlayStation 5: $550
#     - Control DualSense PS5: $85
#     - Starfield: $75
#     - Control Nintendo Pro: $65
#     - Xbox Series X: $500
#     - Final Fantasy XVI: $90
#     - Control Extra Xbox: $68
#
# EXTRAER nombres de productos a lista_nombres
# EXTRAER precios a lista_precios
#
# MOSTRAR "Productos recibidos SIN ORDENAR"
# PARA cada producto en lista original:
#     MOSTRAR número, nombre y precio
# ```
#
# ### PASO 3: ORDENAMIENTO DE PRECIOS
# ```
# CREAR tuplas (nombre, precio) para mantener relación
#
# ORDENAR tuplas por precio de menor a mayor usando SORT()
#
# EXTRAER nombres_ordenados de tuplas ordenadas
# EXTRAER precios_ordenados de tuplas ordenadas
#
# MOSTRAR "Productos ORDENADOS por rango de precio"
# PARA cada producto en lista ordenada:
#     MOSTRAR número, nombre y precio ordenado
# ```
#
# ### PASO 4: CÁLCULO DE IVA (19%)
# ```
# MOSTRAR "Calculando precios finales con IVA..."
#
# CREAR lista_precios_con_iva VACÍA
#
# PARA cada precio en precios_ordenados:
#     precio_final = precio * 1.19
#     AGREGAR precio_final a lista_precios_con_iva
# ```
#
# ### PASO 5: MOSTRAR CATÁLOGO FINAL
# ```
# MOSTRAR "CATÁLOGO FINAL - PRECIOS CON IVA INCLUIDO"
#
# MOSTRAR lista de precios base (sin IVA)
#
# MOSTRAR "Productos con precio FINAL DE VENTA"
# PARA cada (nombre, precio_base, precio_iva) en listas:
#     DETERMINAR categoría (CONSOLA, JUEGO o CONTROL)
#     MOSTRAR número, categoría, nombre
#     MOSTRAR precio base → precio final con IVA
#
# MOSTRAR "Servicio completado"
# ```
#
# ### PASO 6: PROCESO DE COMPRA INTERACTIVO
# ```
# CREAR carrito_compras [] (lista vacía)
# INICIALIZAR total_carrito = 0
#
# ESTABLECER comprar_mas = VERDADERO
#
# MIENTRAS (comprar_mas == VERDADERO):
#
#     MOSTRAR "SELECCIONA UN PRODUCTO PARA COMPRAR"
#     MOSTRAR lista de productos con precios y categorías
#     MOSTRAR opción [0] para finalizar
#
#     REPETIR:
#         PEDIR al usuario: número de producto a comprar
#
#         SI seleccion == 0:
#             ESTABLECER comprar_mas = FALSO
#             SALIR del bucle
#
#         SI seleccion está entre 1 y número_total_productos:
#             OBTENER nombre del producto de la selección
#             OBTENER precio base del producto
#             CALCULAR precio_final = precio_base * 1.19
#             CALCULAR iva = precio_final - precio_base
#             DETERMINAR categoría del producto
#
#             MOSTRAR detalles del producto seleccionado
#             MOSTRAR precio base, IVA y precio final
#
#             PEDIR confirmación: "¿Proceder con la compra?"
#
#             SI confirmación == SÍ:
#                 REPETIR:
#                     PEDIR cantidad a comprar (entre 1 y 10)
#                     SI cantidad está en rango válido:
#                         SALIR del bucle
#                     si no:
#                         MOSTRAR error y pedir de nuevo
#
#                 CALCULAR subtotal = precio_final * cantidad
#                 CREAR registro de compra con:
#                     - categoría
#                     - nombre
#                     - precio unitario
#                     - cantidad
#                     - subtotal
#
#                 AGREGAR registro a carrito_compras
#                 ACTUALIZAR total_carrito += subtotal
#
#                 MOSTRAR confirmación de producto agregado
#                 MOSTRAR total acumulado en carrito
#
#                 PEDIR: "¿Deseas comprar otro producto?"
#                 SI respuesta == NO:
#                     ESTABLECER comprar_mas = FALSO
#
#                 SALIR del bucle
#
#             SI confirmación == NO:
#                 MOSTRAR mensaje de cancelación
#                 SALIR del bucle
#
#         SI seleccion NO es válida:
#             MOSTRAR error de opción inválida
# ```
#
# ### PASO 7: RESUMEN FINAL
# ```
# SI carrito_compras NO está vacío:
#     MOSTRAR "RESUMEN FINAL DE COMPRAS - GAME ZONE"
#     MOSTRAR "DETALLES DE TU CARRITO"
#
#     PARA cada item en carrito_compras:
#         MOSTRAR número, categoría y nombre del producto
#         MOSTRAR precio unitario
#         MOSTRAR cantidad de unidades
#         MOSTRAR subtotal
#
#     MOSTRAR línea separadora
#     MOSTRAR TOTAL A PAGAR
#     MOSTRAR línea separadora
#
#     MOSTRAR mensajes de confirmación:
#         - Compra procesada correctamente
#         - Envío de correo de confirmación
#         - Tiempo de entrega (2-3 días hábiles)
#         - Mensaje de agradecimiento
#
# SI carrito_compras está vacío:
#     MOSTRAR "No realizaste ninguna compra"
#     MOSTRAR mensaje de despedida
# ```
#
# ## FIN DEL PROGRAMA
#
# ---
#
# ### RESUMEN DE VARIABLES PRINCIPALES:
# - `productos`: Lista de tuplas (nombre, precio)
# - `nombres_productos`: Lista de nombres
# - `precios_originales`: Lista de precios sin ordenar
# - `productos_con_precios`: Tuplas ordenadas
# - `precios_ordenados`: Precios del menor al mayor
# - `precios_con_iva`: Precios con IVA aplicado (19%)
# - `carrito_compras`: Lista de compras del cliente
# - `total_carrito`: Suma total de todas las compras
#
# ### FLUJO PRINCIPAL:
# 1. Bienvenida y contexto
# 2. Mostrar productos desordenados
# 3. Ordenar productos por precio
# 4. Calcular precios con IVA
# 5. Mostrar catálogo final
# 6. Permitir compras múltiples con carrito
# 7. Mostrar resumen final
